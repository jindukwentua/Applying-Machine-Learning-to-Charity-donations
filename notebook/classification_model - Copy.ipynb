# %%
# Importing python libraries
#
import pandas as pd
import numpy as np
from scipy.stats import mode
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns; sns.set(style = 'darkgrid')
import requests
from io import StringIO
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV, KFold, cross_val_score
from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import export_graphviz 
from IPython.display import Image  
import pydotplus
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, f1_score
import warnings
warnings.filterwarnings(action = 'ignore')

# %%
train_data = pd.read_csv('../notebook/cleaned_train_data.csv')
test_data = pd.read_csv('../notebook/cleaned_test_data.csv')

# %% [markdown]
# * **control Number is the id of each participant. Therefore control Number will be dropped**

# %%
def drop_column(column_name, data):
    dropped_data = data.drop([column_name], axis = 1) 
    return dropped_data

# %% [markdown]
# ### Dropping the control number column

# %%
train_control_no = train_data.control_number
train_data = drop_column('control_number',train_data)
test_control_no = test_data.control_number
test_data = drop_column('control_number',test_data)

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19372 entries, 0 to 19371
# Data columns (total 49 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   19372 non-null  int64
#  1   donated                      19372 non-null  int64
#  2   months_since_origin          19372 non-null  int64
#  3   donor_age                    19372 non-null  float64
#  4   in_house                     19372 non-null  int64
#  5   urbanicity                   19372 non-null  object
#  6   ses                          19372 non-null  int64
#  7   cluster_code                 19372 non-null  int64
#  8   home_owner                   19372 non-null  object
#  9   donor_gender                 19372 non-null  object
#  10  income_group                 19372 non-null  float64
#  11  published_phone              19372 non-null  int64
#  12  overlay_source               19372 non-null  object
#  13  mor_hit_rate                 19372 non-null  int64
#  14  wealth_rating                19372 non-null  float64
#  15  median_home_value            19372 non-null  int64
#  16  median_household_income      19372 non-null  int64
#  17  pct_owner_occupied           19372 non-null  int64
#  18  per_capita_income            19372 non-null  int64
#  19  pct_attribute1               19372 non-null  int64
#  20  pct_attribute2               19372 non-null  int64
#  21  pct_attribute3               19372 non-null  int64
#  22  pct_attribute4               19372 non-null  int64
#  23  pep_star                     19372 non-null  int64
#  24  recent_star_status           19372 non-null  int64
#  25  recency_status_96nk          19372 non-null  object
#  26  frequency_status_97nk        19372 non-null  int64
#  27  recent_response_prop         19372 non-null  float64
#  28  recent_avg_gift_amt          19372 non-null  float64
#  29  recent_card_response_prop    19372 non-null  float64
#  30  recent_avg_card_gift_amt     19372 non-null  float64
#  31  recent_response_count        19372 non-null  int64
#  32  recent_card_response_count   19372 non-null  int64
#  33  months_since_last_prom_resp  19372 non-null  float64
#  34  lifetime_card_prom           19372 non-null  int64
#  35  lifetime_prom                19372 non-null  int64
#  36  lifetime_gift_amount         19372 non-null  float64
#  37  lifetime_gift_count          19372 non-null  int64
#  38  lifetime_avg_gift_amt        19372 non-null  float64
#  39  lifetime_gift_range          19372 non-null  float64
#  40  lifetime_max_gift_amt        19372 non-null  float64
#  41  lifetime_min_gift_amt        19372 non-null  float64
#  42  last_gift_amt                19372 non-null  float64
#  43  card_prom_12                 19372 non-null  int64
#  44  number_prom_12               19372 non-null  int64
#  45  months_since_last_gift       19372 non-null  int64
#  46  months_since_first_gift      19372 non-null  int64
#  47  file_avg_gift                19372 non-null  float64
#  48  file_card_gift               19372 non-null  int64
# dtypes: float64(15), int64(29), object(5)
# memory usage: 7.2+ MB

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2148 entries, 0 to 2147
# Data columns (total 48 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   2148 non-null   int64
#  1   months_since_origin          2148 non-null   int64
#  2   donor_age                    2148 non-null   float64
#  3   in_house                     2148 non-null   int64
#  4   urbanicity                   2148 non-null   object
#  5   ses                          2148 non-null   int64
#  6   cluster_code                 2148 non-null   int64
#  7   home_owner                   2148 non-null   object
#  8   donor_gender                 2148 non-null   object
#  9   income_group                 2148 non-null   float64
#  10  published_phone              2148 non-null   int64
#  11  overlay_source               2148 non-null   object
#  12  mor_hit_rate                 2148 non-null   int64
#  13  wealth_rating                2148 non-null   float64
#  14  median_home_value            2148 non-null   int64
#  15  median_household_income      2148 non-null   int64
#  16  pct_owner_occupied           2148 non-null   int64
#  17  per_capita_income            2148 non-null   int64
#  18  pct_attribute1               2148 non-null   int64
#  19  pct_attribute2               2148 non-null   int64
#  20  pct_attribute3               2148 non-null   int64
#  21  pct_attribute4               2148 non-null   int64
#  22  pep_star                     2148 non-null   int64
#  23  recent_star_status           2148 non-null   int64
#  24  recency_status_96nk          2148 non-null   object
#  25  frequency_status_97nk        2148 non-null   int64
#  26  recent_response_prop         2148 non-null   float64
#  27  recent_avg_gift_amt          2148 non-null   float64
#  28  recent_card_response_prop    2148 non-null   float64
#  29  recent_avg_card_gift_amt     2148 non-null   float64
#  30  recent_response_count        2148 non-null   int64
#  31  recent_card_response_count   2148 non-null   int64
#  32  months_since_last_prom_resp  2148 non-null   float64
#  33  lifetime_card_prom           2148 non-null   int64
#  34  lifetime_prom                2148 non-null   int64
#  35  lifetime_gift_amount         2148 non-null   float64
#  36  lifetime_gift_count          2148 non-null   int64
#  37  lifetime_avg_gift_amt        2148 non-null   float64
#  38  lifetime_gift_range          2148 non-null   float64
#  39  lifetime_max_gift_amt        2148 non-null   float64
#  40  lifetime_min_gift_amt        2148 non-null   float64
#  41  last_gift_amt                2148 non-null   float64
#  42  card_prom_12                 2148 non-null   int64
#  43  number_prom_12               2148 non-null   int64
#  44  months_since_last_gift       2148 non-null   int64
#  45  months_since_first_gift      2148 non-null   int64
#  46  file_avg_gift                2148 non-null   float64
#  47  file_card_gift               2148 non-null   int64
# dtypes: float64(15), int64(28), object(5)
# memory usage: 805.6+ KB

# %%
train_data.head()
# Out:
#    Unnamed: 0  donated  months_since_origin  donor_age  in_house urbanicity  \
# 0           0        0                  101       87.0         0          X
# 1           1        1                  137       79.0         0          R
# 2           2        0                  113       75.0         0          S
# 3           3        0                   92       60.0         0          U
# 4           4        0                  101       74.0         0          R
#
#    ses  cluster_code home_owner donor_gender  ...  lifetime_gift_range  \
# 0    5            54          H            M  ...                 15.0
# 1    2            45          H            M  ...                 20.0
# 2    1            11          H            F  ...                 23.0
# 3    2             4          H            F  ...                 14.0
# 4    2            49          U            F  ...                 20.0
#
#    lifetime_max_gift_amt lifetime_min_gift_amt  last_gift_amt  card_prom_12  \
# 0                   20.0                   5.0           15.0             5
# 1                   25.0                   5.0           17.0             7
# 2                   28.0                   5.0           19.0            11
# 3                   17.0                   3.0           15.0            11
# 4                   25.0                   5.0           25.0             6
#
#    number_prom_12  months_since_last_gift  months_since_first_gift  \
# 0              12                      26                       92
# 1              21                       7                      122
# 2              32                       6                      105
# 3              33                       6                       92
# 4              19                      18                       92
#
#    file_avg_gift  file_card_gift
# 0           8.49               7
# 1          14.72              12
# 2          16.75              16
# 3          11.76              12
# 4           8.83               3
#
# [5 rows x 49 columns]

# %%
train_data.drop("Unnamed: 0", axis=1, inplace=True)
test_data.drop("Unnamed: 0", axis=1, inplace=True)

# %%
train_data.head()
# Out:
#    donated  months_since_origin  donor_age  in_house urbanicity  ses  \
# 0        0                  101       87.0         0          X    5
# 1        1                  137       79.0         0          R    2
# 2        0                  113       75.0         0          S    1
# 3        0                   92       60.0         0          U    2
# 4        0                  101       74.0         0          R    2
#
#    cluster_code home_owner donor_gender  income_group  ...  \
# 0            54          H            M           2.0  ...
# 1            45          H            M           7.0  ...
# 2            11          H            F           5.0  ...
# 3             4          H            F           6.0  ...
# 4            49          U            F           2.0  ...
#
#    lifetime_gift_range lifetime_max_gift_amt  lifetime_min_gift_amt  \
# 0                 15.0                  20.0                    5.0
# 1                 20.0                  25.0                    5.0
# 2                 23.0                  28.0                    5.0
# 3                 14.0                  17.0                    3.0
# 4                 20.0                  25.0                    5.0
#
#    last_gift_amt  card_prom_12  number_prom_12  months_since_last_gift  \
# 0           15.0             5              12                      26
# 1           17.0             7              21                       7
# 2           19.0            11              32                       6
# 3           15.0            11              33                       6
# 4           25.0             6              19                      18
#
#    months_since_first_gift  file_avg_gift  file_card_gift
# 0                       92           8.49               7
# 1                      122          14.72              12
# 2                      105          16.75              16
# 3                       92          11.76              12
# 4                       92           8.83               3
#
# [5 rows x 48 columns]

# %%
test_data.head()
# Out:
#    months_since_origin  donor_age  in_house urbanicity  ses  cluster_code  \
# 0                  101       59.0         0          R    2            46
# 1                  137       59.0         0          R    2            43
# 2                   17       30.0         0          T    1            35
# 3                  137       75.0         0          U    1             2
# 4                    5       59.0         0          T    2            40
#
#   home_owner donor_gender  income_group  published_phone  ...  \
# 0          U            F           5.0                0  ...
# 1          U            F           5.0                1  ...
# 2          H            M           6.0                1  ...
# 3          H            M           6.0                1  ...
# 4          U            F           2.0                0  ...
#
#   lifetime_gift_range  lifetime_max_gift_amt  lifetime_min_gift_amt  \
# 0                16.0                   21.0                    5.0
# 1                 9.0                   11.0                    2.0
# 2                15.0                   20.0                    5.0
# 3                 5.0                   10.0                    5.0
# 4                 7.0                   10.0                    3.0
#
#    last_gift_amt  card_prom_12  number_prom_12  months_since_last_gift  \
# 0           21.0             4              10                      26
# 1           10.0             9              22                      22
# 2           20.0             5              14                      20
# 3           10.0            10              24                      19
# 4            5.0             5              12                      18
#
#    months_since_first_gift  file_avg_gift  file_card_gift
# 0                       90          14.71               2
# 1                      129           6.00              14
# 2                       87           8.44               1
# 3                      129           6.50              22
# 4                       85           5.83               2
#
# [5 rows x 47 columns]

# %%
train_data.shape, test_data.shape
# Out:
# ((19372, 48), (2148, 47))

# %% [markdown]
# ### Undersampling the whole dataset sometimes causes information leakage, I will be undersampling only the training data

# %%
donated = train_data[train_data['donated']==1]
not_donated = train_data[train_data['donated']==0]
donor_count = train_data['donated'].value_counts()[1]
random_selection = not_donated.sample(donor_count)
train_data_under_sampled = pd.concat([donated, random_selection])

# %%
train_data_under_sampled.shape
# Out:
# (9686, 48)

# %%
train_data_under_sampled['donated'].value_counts()
# Out:
# 1    4843
# 0    4843
# Name: donated, dtype: int64

# %%
# Selecting the independent variables and the target variable
#
y = train_data['donated']
X = train_data.drop('donated', axis = 1)

# %% [markdown]
# * **Joining the Train and Test data to encode the categorical columns together**

# %%
total_data = pd.concat([X, test_data])

# %%
total_data=pd.get_dummies(total_data,drop_first=True)

# %%
total_data.head()
# Out:
#    months_since_origin  donor_age  in_house  ses  cluster_code  income_group  \
# 0                  101       87.0         0    5            54           2.0
# 1                  137       79.0         0    2            45           7.0
# 2                  113       75.0         0    1            11           5.0
# 3                   92       60.0         0    2             4           6.0
# 4                  101       74.0         0    2            49           2.0
#
#    published_phone  mor_hit_rate  wealth_rating  median_home_value  ...  \
# 0                0             0            5.0                554  ...
# 1                0             0            3.0                334  ...
# 2                0             0            9.0               2388  ...
# 3                1             0            4.0               1688  ...
# 4                1             8            5.0                514  ...
#
#    home_owner_U  donor_gender_M  donor_gender_U  overlay_source_M  \
# 0             0               1               0                 0
# 1             0               1               0                 0
# 2             0               0               0                 0
# 3             0               0               0                 0
# 4             1               0               0                 0
#
#    overlay_source_P  recency_status_96nk_E  recency_status_96nk_F  \
# 0                 1                      0                      0
# 1                 1                      0                      0
# 2                 1                      0                      0
# 3                 0                      0                      0
# 4                 0                      0                      0
#
#    recency_status_96nk_L  recency_status_96nk_N  recency_status_96nk_S
# 0                      0                      0                      0
# 1                      0                      0                      1
# 2                      0                      0                      1
# 3                      0                      0                      0
# 4                      0                      0                      0
#
# [5 rows x 57 columns]

# %%
total_data_bf_scaling = total_data

# %% [markdown]
# * **Splitting the Train and Test data to after encoding the categorical columns**

# %%
# from sklearn.preprocessing import MinMaxScaler
# scaler = MinMaxScaler()
# train_d1 = scaler.fit_transform(total_data)
# train_d2 = pd.DataFrame(train_d1,columns=total_data.columns)
# total_data = train_d2

# %%
X_train_cat_encoded =  total_data.iloc[:19372]
X_test_cat_encoded =  total_data.iloc[19372:]
X_train_cat_encoded.shape, X_test_cat_encoded.shape
# Out:
# ((19372, 57), (2148, 57))

# %%
total_data.head()
# Out:
#    months_since_origin  donor_age  in_house  ses  cluster_code  income_group  \
# 0                  101       87.0         0    5            54           2.0
# 1                  137       79.0         0    2            45           7.0
# 2                  113       75.0         0    1            11           5.0
# 3                   92       60.0         0    2             4           6.0
# 4                  101       74.0         0    2            49           2.0
#
#    published_phone  mor_hit_rate  wealth_rating  median_home_value  ...  \
# 0                0             0            5.0                554  ...
# 1                0             0            3.0                334  ...
# 2                0             0            9.0               2388  ...
# 3                1             0            4.0               1688  ...
# 4                1             8            5.0                514  ...
#
#    home_owner_U  donor_gender_M  donor_gender_U  overlay_source_M  \
# 0             0               1               0                 0
# 1             0               1               0                 0
# 2             0               0               0                 0
# 3             0               0               0                 0
# 4             1               0               0                 0
#
#    overlay_source_P  recency_status_96nk_E  recency_status_96nk_F  \
# 0                 1                      0                      0
# 1                 1                      0                      0
# 2                 1                      0                      0
# 3                 0                      0                      0
# 4                 0                      0                      0
#
#    recency_status_96nk_L  recency_status_96nk_N  recency_status_96nk_S
# 0                      0                      0                      0
# 1                      0                      0                      1
# 2                      0                      0                      1
# 3                      0                      0                      0
# 4                      0                      0                      0
#
# [5 rows x 57 columns]

# %%
# Splitting the data into training and testing sets
#
X_train, X_test, y_train, y_test = train_test_split(X_train_cat_encoded, y, test_size = 0.3, random_state = 101)

# %%
# define and configure the model
model = KNeighborsClassifier()
# fit the model
model.fit(X_train, y_train)
# evaluate the model
preds = model.predict(X_test)
print('Accuracy : ',accuracy_score(y_test, preds))

# Measuring the accuracy of the model
#
print(f'The accuracy score is: {accuracy_score(y_test, preds)} and the f1 score is {f1_score(y_test, preds)}')
print('\n')
print(f'{classification_report(y_test, preds)}')
confusion_matrix(y_test, preds)
# Out:
# Accuracy :  0.7068134893324157
# The accuracy score is: 0.7068134893324157 and the f1 score is 0.16796875
#
#
#               precision    recall  f1-score   support
#
#            0       0.76      0.89      0.82      4398
#            1       0.27      0.12      0.17      1414
#
#     accuracy                           0.71      5812
#    macro avg       0.52      0.51      0.50      5812
# weighted avg       0.64      0.71      0.66      5812
# array([[3936,  462],
#        [1242,  172]], dtype=int64)

# %%
# define and configure the model
model = DecisionTreeClassifier()
# fit the model
model.fit(X_train, y_train)
# evaluate the model
preds = model.predict(X_test)
print('Accuracy : ',accuracy_score(y_test, preds))

print(f'The accuracy score is: {accuracy_score(y_test, preds)} and the f1 score is {f1_score(y_test, preds)}')
print('\n')
print(f'{classification_report(y_test, preds)}')
confusion_matrix(y_test, preds)
# Out:
# Accuracy :  0.6278389538885065
# The accuracy score is: 0.6278389538885065 and the f1 score is 0.27294117647058824
#
#
#               precision    recall  f1-score   support
#
#            0       0.76      0.74      0.75      4398
#            1       0.26      0.29      0.27      1414
#
#     accuracy                           0.63      5812
#    macro avg       0.51      0.51      0.51      5812
# weighted avg       0.64      0.63      0.63      5812
# array([[3243, 1155],
#        [1008,  406]], dtype=int64)

# %%
# Checking for the most important features that contribute most in predicting the target
# Creating a dataframe of features and their respective importances
#
dc_impo_df = pd.DataFrame({'feature': X_train_cat_encoded.columns, 'importance': np.round(model.feature_importances_, 4)}).set_index('feature').sort_values(by = 'importance', ascending = False)
dc_impo_df
# Out:
#                              importance
# feature
# median_home_value                0.0560
# per_capita_income                0.0493
# pct_owner_occupied               0.0490
# median_household_income          0.0479
# pct_attribute2                   0.0429
# donor_age                        0.0421
# pct_attribute4                   0.0413
# lifetime_gift_amount             0.0349
# pct_attribute3                   0.0344
# months_since_first_gift          0.0329
# cluster_code                     0.0304
# recent_response_prop             0.0297
# recent_avg_gift_amt              0.0265
# recent_avg_card_gift_amt         0.0256
# months_since_last_prom_resp      0.0248
# mor_hit_rate                     0.0239
# number_prom_12                   0.0226
# lifetime_prom                    0.0223
# months_since_last_gift           0.0218
# file_avg_gift                    0.0216
# lifetime_gift_range              0.0214
# file_card_gift                   0.0212
# recent_card_response_prop        0.0200
# lifetime_avg_gift_amt            0.0192
# pct_attribute1                   0.0183
# frequency_status_97nk            0.0182
# lifetime_card_prom               0.0172
# income_group                     0.0172
# lifetime_gift_count              0.0161
# last_gift_amt                    0.0155
# wealth_rating                    0.0144
# lifetime_max_gift_amt            0.0128
# card_prom_12                     0.0121
# recent_response_count            0.0112
# recent_card_response_count       0.0080
# lifetime_min_gift_amt            0.0080
# recent_star_status               0.0079
# ses                              0.0056
# pep_star                         0.0056
# home_owner_U                     0.0054
# overlay_source_P                 0.0053
# published_phone                  0.0052
# donor_gender_M                   0.0052
# months_since_origin              0.0037
# urbanicity_S                     0.0037
# overlay_source_M                 0.0031
# urbanicity_T                     0.0029
# donor_gender_U                   0.0026
# in_house                         0.0025
# recency_status_96nk_S            0.0022
# urbanicity_R                     0.0020
# urbanicity_U                     0.0017
# recency_status_96nk_E            0.0015
# recency_status_96nk_L            0.0010
# recency_status_96nk_N            0.0010
# recency_status_96nk_F            0.0006
# urbanicity_X                     0.0004

# %%
# Creating a bar chart of feature importance in descending order
#
dc_impo_df = dc_impo_df[:20].sort_values(by = 'importance', ascending = False)
dc_impo_df.plot(kind = 'barh', figsize = (10, 10), color = 'purple')
plt.legend(loc = 'center right')
plt.title('Bar chart showing feature importance', color = 'indigo', fontsize = 14)
plt.xlabel('Features', fontsize = 12, color = 'indigo')
plt.show()

# %%
# define and configure the model
model = XGBClassifier()
# fit the model
model.fit(X_train, y_train)
# evaluate the model
preds = model.predict(X_test)
print('Accuracy : ',accuracy_score(y_test, preds))

print(f'The accuracy score is: {accuracy_score(y_test, preds)} and the f1 score is {f1_score(y_test, preds)}')
print('\n')
print(f'{classification_report(y_test, preds)}')
confusion_matrix(y_test, preds)
# Out:
# [10:40:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Accuracy :  0.7370956641431521
# The accuracy score is: 0.7370956641431521 and the f1 score is 0.1776103336921421
#
#
#               precision    recall  f1-score   support
#
#            0       0.77      0.94      0.84      4398
#            1       0.37      0.12      0.18      1414
#
#     accuracy                           0.74      5812
#    macro avg       0.57      0.53      0.51      5812
# weighted avg       0.67      0.74      0.68      5812
# array([[4119,  279],
#        [1249,  165]], dtype=int64)

# %%
# Checking for the most important features that contribute most in predicting the target
# Creating a dataframe of features and their respective importances
#
impo_df = pd.DataFrame({'feature': X_train_cat_encoded.columns, 'importance': np.round(model.feature_importances_, 4)}).set_index('feature').sort_values(by = 'importance', ascending = False)
impo_df
# Out:
#                              importance
# feature
# frequency_status_97nk            0.0743
# recent_card_response_count       0.0340
# pep_star                         0.0272
# card_prom_12                     0.0272
# urbanicity_R                     0.0241
# recency_status_96nk_N            0.0210
# overlay_source_P                 0.0210
# lifetime_gift_count              0.0207
# overlay_source_M                 0.0195
# ses                              0.0195
# months_since_last_gift           0.0195
# donor_gender_U                   0.0190
# lifetime_max_gift_amt            0.0190
# income_group                     0.0189
# urbanicity_S                     0.0186
# lifetime_avg_gift_amt            0.0185
# median_home_value                0.0184
# last_gift_amt                    0.0183
# cluster_code                     0.0178
# median_household_income          0.0177
# recent_card_response_prop        0.0174
# pct_attribute1                   0.0173
# mor_hit_rate                     0.0172
# donor_age                        0.0172
# recency_status_96nk_F            0.0171
# pct_owner_occupied               0.0170
# per_capita_income                0.0168
# months_since_last_prom_resp      0.0168
# pct_attribute2                   0.0167
# file_card_gift                   0.0166
# months_since_first_gift          0.0166
# recent_response_prop             0.0166
# lifetime_prom                    0.0166
# lifetime_gift_range              0.0165
# months_since_origin              0.0163
# wealth_rating                    0.0162
# donor_gender_M                   0.0162
# lifetime_min_gift_amt            0.0161
# pct_attribute3                   0.0158
# pct_attribute4                   0.0157
# recency_status_96nk_L            0.0156
# recent_response_count            0.0152
# lifetime_gift_amount             0.0151
# recent_avg_gift_amt              0.0151
# recency_status_96nk_S            0.0149
# lifetime_card_prom               0.0147
# home_owner_U                     0.0146
# number_prom_12                   0.0145
# recent_star_status               0.0143
# recent_avg_card_gift_amt         0.0142
# published_phone                  0.0138
# urbanicity_T                     0.0114
# in_house                         0.0111
# recency_status_96nk_E            0.0085
# urbanicity_U                     0.0000
# file_avg_gift                    0.0000
# urbanicity_X                     0.0000

# %%
# Creating a bar chart of feature importance in descending order
#
impo_df = impo_df[:10].sort_values(by = 'importance', ascending = False)
impo_df.plot(kind = 'barh', figsize = (10, 10), color = 'purple')
plt.legend(loc = 'center right')
plt.title('Bar chart showing feature importance', color = 'indigo', fontsize = 14)
plt.xlabel('Features', fontsize = 12, color = 'indigo')
plt.show()

# %%
# define and configure the model
model = CatBoostClassifier(verbose=False)

# fit the model
model.fit(X_train, y_train)

# evaluate the model
preds = model.predict(X_test)
print('Accuracy : ',accuracy_score(y_test, preds))

print(f'The accuracy score is: {accuracy_score(y_test, preds)} and the f1 score is {f1_score(y_test, preds)}')
print('\n')
print(f'{classification_report(y_test, preds)}')
confusion_matrix(y_test, preds)
# Out:
# Accuracy :  0.7558499655884378
# The accuracy score is: 0.7558499655884378 and the f1 score is 0.11478477854023705
#
#
#               precision    recall  f1-score   support
#
#            0       0.76      0.98      0.86      4398
#            1       0.49      0.07      0.11      1414
#
#     accuracy                           0.76      5812
#    macro avg       0.63      0.52      0.49      5812
# weighted avg       0.70      0.76      0.68      5812
# array([[4301,   97],
#        [1322,   92]], dtype=int64)

# %%
# Checking for the most important features that contribute most in predicting the target
# Creating a dataframe of features and their respective importances
#
impo_df = pd.DataFrame({'feature': X_train_cat_encoded.columns, 'importance': np.round(model.feature_importances_, 4)}).set_index('feature').sort_values(by = 'importance', ascending = False)
impo_df
# Out:
#                              importance
# feature
# donor_age                        5.1496
# median_home_value                5.0365
# median_household_income          4.6331
# pct_owner_occupied               4.3947
# per_capita_income                4.2978
# pct_attribute4                   4.1750
# pct_attribute2                   3.7774
# pct_attribute3                   3.4204
# recent_response_prop             2.9285
# lifetime_gift_amount             2.8629
# months_since_last_gift           2.7854
# months_since_first_gift          2.7751
# recent_avg_gift_amt              2.7566
# cluster_code                     2.6890
# number_prom_12                   2.6590
# lifetime_prom                    2.4729
# last_gift_amt                    2.3058
# mor_hit_rate                     2.2793
# months_since_last_prom_resp      2.2433
# income_group                     2.2133
# recent_avg_card_gift_amt         2.1085
# recent_card_response_prop        2.0626
# lifetime_gift_count              1.9977
# lifetime_gift_range              1.9532
# file_card_gift                   1.8482
# lifetime_avg_gift_amt            1.8286
# file_avg_gift                    1.7634
# wealth_rating                    1.6371
# frequency_status_97nk            1.4578
# lifetime_min_gift_amt            1.3675
# lifetime_max_gift_amt            1.3060
# card_prom_12                     1.2472
# pep_star                         1.2464
# lifetime_card_prom               1.2395
# recent_response_count            1.2021
# pct_attribute1                   1.1862
# recent_star_status               0.8909
# months_since_origin              0.8298
# ses                              0.8082
# recent_card_response_count       0.7655
# in_house                         0.6850
# urbanicity_R                     0.6044
# published_phone                  0.5599
# donor_gender_M                   0.4346
# overlay_source_M                 0.4217
# recency_status_96nk_S            0.3922
# donor_gender_U                   0.3478
# home_owner_U                     0.3335
# urbanicity_S                     0.3090
# urbanicity_T                     0.3022
# recency_status_96nk_E            0.2667
# overlay_source_P                 0.2018
# urbanicity_U                     0.1769
# recency_status_96nk_N            0.1406
# recency_status_96nk_F            0.0976
# urbanicity_X                     0.0818
# recency_status_96nk_L            0.0423

# %%
# Creating a bar chart of feature importance in descending order
#
impo_df = impo_df[:10].sort_values(by = 'importance', ascending = False)
impo_df.plot(kind = 'barh', figsize = (10, 10), color = 'purple')
plt.legend(loc = 'center right')
plt.title('Bar chart showing feature importance', color = 'indigo', fontsize = 14)
plt.xlabel('Features', fontsize = 12, color = 'indigo')
plt.show()

# %%
# define and configure the model
# l1 regularization gives better results
model = LogisticRegression()
# fit the model
model.fit(X_train, y_train)

# evaluate the model
preds = model.predict(X_test)
print('Accuracy : ',accuracy_score(y_test, preds))

print(f'The accuracy score is: {accuracy_score(y_test, preds)} and the f1 score is {f1_score(y_test, preds)}')
print('\n')
print(f'{classification_report(y_test, preds)}')
confusion_matrix(y_test, preds)
# Out:
# Accuracy :  0.755677907777013
# The accuracy score is: 0.755677907777013 and the f1 score is 0.0056022408963585435
#
#
#               precision    recall  f1-score   support
#
#            0       0.76      1.00      0.86      4398
#            1       0.29      0.00      0.01      1414
#
#     accuracy                           0.76      5812
#    macro avg       0.52      0.50      0.43      5812
# weighted avg       0.64      0.76      0.65      5812
# array([[4388,   10],
#        [1410,    4]], dtype=int64)

# %%
# define and configure the model
model = AdaBoostClassifier()

# fit the model
model.fit(X_train, y_train)

# evaluate the model
preds = model.predict(X_test)
print('Accuracy : ',accuracy_score(y_test, preds))

print(f'The accuracy score is: {accuracy_score(y_test, preds)} and the f1 score is {f1_score(y_test, preds)}')
print('\n')
print(f'{classification_report(y_test, preds)}')
confusion_matrix(y_test, preds)
# Out:
# Accuracy :  0.7570543702684102
# The accuracy score is: 0.7570543702684102 and the f1 score is 0.09718670076726343
#
#
#               precision    recall  f1-score   support
#
#            0       0.76      0.98      0.86      4398
#            1       0.51      0.05      0.10      1414
#
#     accuracy                           0.76      5812
#    macro avg       0.64      0.52      0.48      5812
# weighted avg       0.70      0.76      0.67      5812
# array([[4324,   74],
#        [1338,   76]], dtype=int64)

# %%
# Checking for the most important features that contribute most in predicting the target
# Creating a dataframe of features and their respective importances
#
impo_df = pd.DataFrame({'feature': X_train_cat_encoded.columns, 'importance': np.round(model.feature_importances_, 4)}).set_index('feature').sort_values(by = 'importance', ascending = False)
impo_df
# Out:
#                              importance
# feature
# frequency_status_97nk              0.08
# months_since_first_gift            0.08
# months_since_last_gift             0.06
# number_prom_12                     0.06
# lifetime_avg_gift_amt              0.06
# median_home_value                  0.06
# median_household_income            0.04
# pct_owner_occupied                 0.04
# pct_attribute4                     0.04
# donor_age                          0.04
# recent_card_response_prop          0.04
# mor_hit_rate                       0.04
# last_gift_amt                      0.04
# recent_avg_gift_amt                0.02
# lifetime_gift_range                0.02
# lifetime_max_gift_amt              0.02
# lifetime_gift_count                0.02
# lifetime_card_prom                 0.02
# recent_avg_card_gift_amt           0.02
# file_avg_gift                      0.02
# months_since_origin                0.02
# lifetime_prom                      0.02
# ses                                0.02
# recent_star_status                 0.02
# cluster_code                       0.02
# pep_star                           0.02
# pct_attribute3                     0.02
# income_group                       0.02
# pct_attribute2                     0.02
# donor_gender_M                     0.00
# urbanicity_U                       0.00
# urbanicity_X                       0.00
# home_owner_U                       0.00
# overlay_source_M                   0.00
# donor_gender_U                     0.00
# urbanicity_S                       0.00
# overlay_source_P                   0.00
# recency_status_96nk_E              0.00
# recency_status_96nk_F              0.00
# recency_status_96nk_L              0.00
# recency_status_96nk_N              0.00
# urbanicity_T                       0.00
# recent_response_prop               0.00
# urbanicity_R                       0.00
# file_card_gift                     0.00
# in_house                           0.00
# card_prom_12                       0.00
# published_phone                    0.00
# lifetime_min_gift_amt              0.00
# wealth_rating                      0.00
# per_capita_income                  0.00
# pct_attribute1                     0.00
# lifetime_gift_amount               0.00
# months_since_last_prom_resp        0.00
# recent_card_response_count         0.00
# recent_response_count              0.00
# recency_status_96nk_S              0.00

# %%
# Creating a bar chart of feature importance in descending order
#
impo_df = impo_df[:10].sort_values(by = 'importance', ascending = False)
impo_df.plot(kind = 'barh', figsize = (10, 10), color = 'purple')
plt.legend(loc = 'center right')
plt.title('Bar chart showing feature importance', color = 'indigo', fontsize = 14)
plt.xlabel('Features', fontsize = 12, color = 'indigo')
plt.show()

# %%
# define and configure the model
model = RandomForestClassifier()

# fit the model
model.fit(X_train, y_train)

# evaluate the model
preds = model.predict(X_test)
print('Accuracy : ',accuracy_score(y_test, preds))

print(f'The accuracy score is: {accuracy_score(y_test, preds)} and the f1 score is {f1_score(y_test, preds)}')
print('\n')
print(f'{classification_report(y_test, preds)}')
confusion_matrix(y_test, preds)
# Out:
# Accuracy :  0.7570543702684102
# The accuracy score is: 0.7570543702684102 and the f1 score is 0.09020618556701031
#
#
#               precision    recall  f1-score   support
#
#            0       0.76      0.98      0.86      4398
#            1       0.51      0.05      0.09      1414
#
#     accuracy                           0.76      5812
#    macro avg       0.64      0.52      0.48      5812
# weighted avg       0.70      0.76      0.67      5812
# array([[4330,   68],
#        [1344,   70]], dtype=int64)

# %%
# Checking for the most important features that contribute most in predicting the target
# Creating a dataframe of features and their respective importances
#
rf_impo_df = pd.DataFrame({'feature': X_train_cat_encoded.columns, 'importance': np.round(model.feature_importances_, 4)}).set_index('feature').sort_values(by = 'importance', ascending = False)
rf_impo_df
# Out:
#                              importance
# feature
# median_home_value                0.0437
# per_capita_income                0.0416
# median_household_income          0.0399
# pct_owner_occupied               0.0357
# pct_attribute4                   0.0356
# pct_attribute2                   0.0351
# pct_attribute3                   0.0338
# donor_age                        0.0335
# file_avg_gift                    0.0320
# lifetime_avg_gift_amt            0.0315
# lifetime_gift_amount             0.0310
# cluster_code                     0.0308
# recent_response_prop             0.0308
# lifetime_prom                    0.0294
# months_since_first_gift          0.0292
# recent_avg_gift_amt              0.0287
# months_since_last_gift           0.0238
# lifetime_card_prom               0.0236
# number_prom_12                   0.0233
# recent_avg_card_gift_amt         0.0233
# recent_card_response_prop        0.0222
# last_gift_amt                    0.0218
# lifetime_gift_range              0.0214
# months_since_last_prom_resp      0.0214
# lifetime_gift_count              0.0214
# mor_hit_rate                     0.0191
# file_card_gift                   0.0183
# lifetime_max_gift_amt            0.0180
# income_group                     0.0176
# wealth_rating                    0.0151
# recent_response_count            0.0143
# lifetime_min_gift_amt            0.0138
# months_since_origin              0.0134
# card_prom_12                     0.0126
# recent_card_response_count       0.0123
# pct_attribute1                   0.0111
# frequency_status_97nk            0.0108
# ses                              0.0091
# recent_star_status               0.0076
# published_phone                  0.0063
# donor_gender_M                   0.0063
# home_owner_U                     0.0057
# pep_star                         0.0052
# overlay_source_M                 0.0052
# overlay_source_P                 0.0048
# urbanicity_S                     0.0044
# urbanicity_T                     0.0044
# donor_gender_U                   0.0034
# urbanicity_R                     0.0034
# urbanicity_U                     0.0029
# in_house                         0.0027
# recency_status_96nk_S            0.0027
# recency_status_96nk_N            0.0015
# recency_status_96nk_E            0.0012
# urbanicity_X                     0.0009
# recency_status_96nk_F            0.0009
# recency_status_96nk_L            0.0004

# %%
# Creating a bar chart of feature importance in descending order
#
rf_impo_df = rf_impo_df[:20].sort_values(by = 'importance', ascending = True)
rf_impo_df.plot(kind = 'barh', figsize = (10, 10), color = 'purple')
plt.legend(loc = 'center right')
plt.title('Bar chart showing feature importance', color = 'indigo', fontsize = 14)
plt.xlabel('Features', fontsize = 12, color = 'indigo')
plt.show()

# %% [markdown]
# ### Using the most important features to build a random forest model

# %%
rf_impo_df.index
# Out:
# Index(['recent_avg_card_gift_amt', 'number_prom_12', 'lifetime_card_prom',
#        'months_since_last_gift', 'recent_avg_gift_amt',
#        'months_since_first_gift', 'lifetime_prom', 'recent_response_prop',
#        'cluster_code', 'lifetime_gift_amount', 'lifetime_avg_gift_amt',
#        'file_avg_gift', 'donor_age', 'pct_attribute3', 'pct_attribute2',
#        'pct_attribute4', 'pct_owner_occupied', 'median_household_income',
#        'per_capita_income', 'median_home_value'],
#       dtype='object', name='feature')

# %% [markdown]
# # Data Modelling

# %% [markdown]
# ## Random Forest Classifier

# %% [markdown]
# ### Remodelling with the most important features only

# %%
# Selecting only important features and the y variable
#
X = X[rf_impo_df.index]

y = y

# %%
X.shape, y.shape
# Out:
# ((19372, 20), (19372,))

# %%
# Splitting the data into training and testing sets
#
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 101)

# define and configure the model
model = RandomForestClassifier()

# fit the model
model.fit(X_train, y_train)

# evaluate the model
preds = model.predict(X_test)
print('Accuracy : ',accuracy_score(y_test, preds))

print(f'The accuracy score is: {accuracy_score(y_test, preds)} and the f1 score is {f1_score(y_test, preds)}')
print('\n')
print(f'{classification_report(y_test, preds)}')
confusion_matrix(y_test, preds)
# Out:
# Accuracy :  0.7510323468685478
# The accuracy score is: 0.7510323468685478 and the f1 score is 0.08126984126984127
#
#
#               precision    recall  f1-score   support
#
#            0       0.76      0.98      0.86      4398
#            1       0.40      0.05      0.08      1414
#
#     accuracy                           0.75      5812
#    macro avg       0.58      0.51      0.47      5812
# weighted avg       0.67      0.75      0.67      5812
# array([[4301,   97],
#        [1350,   64]], dtype=int64)

# %%
# Selecting the independent variables and the target variable
#
y = train_data_under_sampled['donated']
X = train_data_under_sampled.drop('donated', axis = 1)

# %% [markdown]
# * **Joining the Train and Test data to encode the categorical columns together**

# %%
total_data = pd.concat([X, test_data])

# %%
total_data=pd.get_dummies(total_data,drop_first=True)

# %%
total_data.head()
# Out:
#     months_since_origin  donor_age  in_house  ses  cluster_code  income_group  \
# 1                   137       79.0         0    2            45           7.0
# 7                    89       79.0         0    2            28           1.0
# 9                   101       63.0         0    2            43           4.0
# 14                  137       60.0         0    2            43           5.0
# 16                   77       81.0         0    2            45           4.0
#
#     published_phone  mor_hit_rate  wealth_rating  median_home_value  ...  \
# 1                 0             0            3.0                334  ...
# 7                 0             0            5.0               1004  ...
# 9                 1             0            5.0                399  ...
# 14                1             0            1.0                475  ...
# 16                1            24            3.0                530  ...
#
#     home_owner_U  donor_gender_M  donor_gender_U  overlay_source_M  \
# 1              0               1               0                 0
# 7              0               0               0                 0
# 9              0               0               0                 0
# 14             1               0               0                 1
# 16             1               1               0                 0
#
#     overlay_source_P  recency_status_96nk_E  recency_status_96nk_F  \
# 1                  1                      0                      0
# 7                  1                      0                      0
# 9                  0                      0                      0
# 14                 0                      0                      0
# 16                 0                      0                      0
#
#     recency_status_96nk_L  recency_status_96nk_N  recency_status_96nk_S
# 1                       0                      0                      1
# 7                       0                      0                      0
# 9                       0                      0                      1
# 14                      0                      0                      1
# 16                      0                      0                      0
#
# [5 rows x 57 columns]

# %%
total_data.shape
# Out:
# (11834, 57)

# %% [markdown]
# * **Splitting the Train and Test data to after encoding the categorical columns**

# %%
# from sklearn.preprocessing import MinMaxScaler
# scaler = MinMaxScaler()
# train_d1 = scaler.fit_transform(total_data)
# train_d2 = pd.DataFrame(train_d1,columns=total_data.columns)
# total_data = train_d2

# %%
X_train_cat_encoded =  total_data.iloc[:9686]
X_test_cat_encoded =  total_data.iloc[9686:]
X_train_cat_encoded.shape, X_test_cat_encoded.shape
# Out:
# ((9686, 57), (2148, 57))

# %%
total_data.head()
# Out:
#     months_since_origin  donor_age  in_house  ses  cluster_code  income_group  \
# 1                   137       79.0         0    2            45           7.0
# 7                    89       79.0         0    2            28           1.0
# 9                   101       63.0         0    2            43           4.0
# 14                  137       60.0         0    2            43           5.0
# 16                   77       81.0         0    2            45           4.0
#
#     published_phone  mor_hit_rate  wealth_rating  median_home_value  ...  \
# 1                 0             0            3.0                334  ...
# 7                 0             0            5.0               1004  ...
# 9                 1             0            5.0                399  ...
# 14                1             0            1.0                475  ...
# 16                1            24            3.0                530  ...
#
#     home_owner_U  donor_gender_M  donor_gender_U  overlay_source_M  \
# 1              0               1               0                 0
# 7              0               0               0                 0
# 9              0               0               0                 0
# 14             1               0               0                 1
# 16             1               1               0                 0
#
#     overlay_source_P  recency_status_96nk_E  recency_status_96nk_F  \
# 1                  1                      0                      0
# 7                  1                      0                      0
# 9                  0                      0                      0
# 14                 0                      0                      0
# 16                 0                      0                      0
#
#     recency_status_96nk_L  recency_status_96nk_N  recency_status_96nk_S
# 1                       0                      0                      1
# 7                       0                      0                      0
# 9                       0                      0                      1
# 14                      0                      0                      1
# 16                      0                      0                      0
#
# [5 rows x 57 columns]

# %%
# Splitting the data into training and testing sets
#
X_train, X_test, y_train, y_test = train_test_split(X_train_cat_encoded, y, test_size = 0.3, random_state = 101)

# %%
## define and configure the model
model = RandomForestClassifier()

# fit the model
model.fit(X_train, y_train)

# evaluate the model
preds = model.predict(X_test)
print('Accuracy : ',accuracy_score(y_test, preds))

print(f'The accuracy score is: {accuracy_score(y_test, preds)} and the f1 score is {f1_score(y_test, preds)}')
print('\n')
print(f'{classification_report(y_test, preds)}')
confusion_matrix(y_test, preds)
# Out:
# Accuracy :  0.5677907777013076
# The accuracy score is: 0.5677907777013076 and the f1 score is 0.5527065527065528
#
#
#               precision    recall  f1-score   support
#
#            0       0.56      0.60      0.58      1446
#            1       0.58      0.53      0.55      1460
#
#     accuracy                           0.57      2906
#    macro avg       0.57      0.57      0.57      2906
# weighted avg       0.57      0.57      0.57      2906
# array([[874, 572],
#        [684, 776]], dtype=int64)

# %%
# Checking for the most important features that contribute most in predicting the target
# Creating a dataframe of features and their respective importances
#
rf_impo_df = pd.DataFrame({'feature': X_train_cat_encoded.columns, 'importance': np.round(model.feature_importances_, 4)}).set_index('feature').sort_values(by = 'importance', ascending = False)
rf_impo_df
# Out:
#                              importance
# feature
# median_home_value                0.0426
# per_capita_income                0.0422
# median_household_income          0.0399
# pct_owner_occupied               0.0374
# pct_attribute4                   0.0355
# donor_age                        0.0351
# pct_attribute2                   0.0345
# pct_attribute3                   0.0344
# file_avg_gift                    0.0319
# lifetime_gift_amount             0.0314
# cluster_code                     0.0314
# lifetime_avg_gift_amt            0.0312
# recent_response_prop             0.0309
# months_since_first_gift          0.0298
# lifetime_prom                    0.0289
# recent_avg_gift_amt              0.0282
# months_since_last_gift           0.0235
# lifetime_card_prom               0.0234
# recent_card_response_prop        0.0230
# recent_avg_card_gift_amt         0.0226
# number_prom_12                   0.0220
# lifetime_gift_range              0.0217
# months_since_last_prom_resp      0.0210
# last_gift_amt                    0.0209
# lifetime_gift_count              0.0203
# file_card_gift                   0.0198
# lifetime_max_gift_amt            0.0190
# mor_hit_rate                     0.0186
# income_group                     0.0180
# recent_response_count            0.0151
# wealth_rating                    0.0150
# months_since_origin              0.0137
# lifetime_min_gift_amt            0.0131
# recent_card_response_count       0.0127
# card_prom_12                     0.0112
# pct_attribute1                   0.0105
# frequency_status_97nk            0.0102
# ses                              0.0099
# recent_star_status               0.0079
# published_phone                  0.0065
# donor_gender_M                   0.0064
# home_owner_U                     0.0055
# pep_star                         0.0052
# overlay_source_M                 0.0052
# overlay_source_P                 0.0050
# urbanicity_T                     0.0045
# urbanicity_S                     0.0042
# urbanicity_R                     0.0039
# urbanicity_U                     0.0033
# recency_status_96nk_S            0.0029
# donor_gender_U                   0.0027
# in_house                         0.0023
# recency_status_96nk_N            0.0013
# recency_status_96nk_E            0.0011
# recency_status_96nk_F            0.0010
# urbanicity_X                     0.0009
# recency_status_96nk_L            0.0002

# %%
# Creating a bar chart of feature importance in descending order
#
rf_impo_df = rf_impo_df[:20].sort_values(by = 'importance', ascending = True)
rf_impo_df.plot(kind = 'barh', figsize = (10, 10), color = 'purple')
plt.legend(loc = 'center right')
plt.title('Bar chart showing feature importance', color = 'indigo', fontsize = 14)
plt.xlabel('Features', fontsize = 12, color = 'indigo')
plt.show()

# %%
rf_impo_df.index
# Out:
# Index(['recent_avg_card_gift_amt', 'recent_card_response_prop',
#        'lifetime_card_prom', 'months_since_last_gift', 'recent_avg_gift_amt',
#        'lifetime_prom', 'months_since_first_gift', 'recent_response_prop',
#        'lifetime_avg_gift_amt', 'cluster_code', 'lifetime_gift_amount',
#        'file_avg_gift', 'pct_attribute3', 'pct_attribute2', 'donor_age',
#        'pct_attribute4', 'pct_owner_occupied', 'median_household_income',
#        'per_capita_income', 'median_home_value'],
#       dtype='object', name='feature')

# %% [markdown]
# ### Modelling the undersampled data with the most important features

# %%
# Selecting only important features and the y variable
#
X = X[rf_impo_df.index]

y = y

# %%
X.shape, y.shape
# Out:
# ((9686, 20), (9686,))

# %%
# Splitting the data into training and testing sets
#
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 101)

## define and configure the model
model = RandomForestClassifier()

# fit the model
model.fit(X_train, y_train)

# evaluate the model
preds = model.predict(X_test)
print('Accuracy : ',accuracy_score(y_test, preds))

print(f'The accuracy score is: {accuracy_score(y_test, preds)} and the f1 score is {f1_score(y_test, preds)}')
print('\n')
print(f'{classification_report(y_test, preds)}')
confusion_matrix(y_test, preds)
# Out:
# Accuracy :  0.5629731589814178
# The accuracy score is: 0.5629731589814178 and the f1 score is 0.549645390070922
#
#
#               precision    recall  f1-score   support
#
#            0       0.56      0.60      0.58      1446
#            1       0.57      0.53      0.55      1460
#
#     accuracy                           0.56      2906
#    macro avg       0.56      0.56      0.56      2906
# weighted avg       0.56      0.56      0.56      2906
# array([[861, 585],
#        [685, 775]], dtype=int64)

# %% [markdown]
# ### Undersampling leads to a remarkable imporovement in the recall and f1-score

# %% [markdown]
# ### Parameter Tuning

# %%
# Previewing the parameters to tune
#
RandomForestClassifier()
# Out:
# RandomForestClassifier()

# %%
# Creating a dictionary of parameters to tune
#
params = {'n_estimators': [10, 20, 30, 50, 100],
         'max_depth': [1, 2, 3, 4, 5]}

# Setting the number of folds to 10 and instantiating the model
# 
kfold = KFold(n_splits=10, shuffle=True)
model = RandomForestClassifier()

search = GridSearchCV(model, param_grid=params, scoring = 'f1', cv = kfold)

# Fitting the grid search with the X and the y variables
#
search.fit(X, y)

# Checking for the best parameters
#
print(f'The best parameters are: {search.best_params_}')
# Out:
# The best parameters are: {'max_depth': 5, 'n_estimators': 20}

# %%
X.shape
# Out:
# (9686, 20)

# %%
# Applying the best parameters to the model


# Splitting the data into training and testing sets
#
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 101)

## define and configure the model
model = RandomForestClassifier(max_depth = 5, n_estimators = 20)

# fit the model
model.fit(X_train, y_train)

# evaluate the model
preds = model.predict(X_test)
print('Accuracy : ',accuracy_score(y_test, preds))

print(f'The accuracy score is: {accuracy_score(y_test, preds)} and the f1 score is {f1_score(y_test, preds)}')
print('\n')
print(f'{classification_report(y_test, preds)}')
confusion_matrix(y_test, preds)
# Out:
# Accuracy :  0.5760495526496903
# The accuracy score is: 0.5760495526496903 and the f1 score is 0.5574712643678161
#
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.62      0.59      1446
#            1       0.59      0.53      0.56      1460
#
#     accuracy                           0.58      2906
#    macro avg       0.58      0.58      0.58      2906
# weighted avg       0.58      0.58      0.58      2906
# array([[898, 548],
#        [684, 776]], dtype=int64)

# %% [markdown]
# *Parameter tuning hasn't decreased or increased the f1 score*

# %% [markdown]
# ### Cross Validation to check for the stability of the model

# %%
# Performing cross validation of ten folds
#
scores = cross_val_score(model, X, y, scoring = 'f1', cv = 10)

# Calculating the mean of the cross validation scores
#
print(f'Mean of cross validation scores is {scores.mean()}')

# Calculating the variance of the cross validation scores from the mean
#
print(f'Standard deviation of the cross validation scores is {scores.std()}')
# Out:
# Mean of cross validation scores is 0.4895089717336685
# Standard deviation of the cross validation scores is 0.05740354167271765

# %% [markdown]
# ## Challenging the solution

# %% [markdown]
# *Using different models to check whether performance can be improved*

# %%
X_test_cat_encoded = X_test_cat_encoded[rf_impo_df.index]

# %%
X_test_cat_encoded.shape

# %%
X_test_cat_encoded.head()

# %%
y__ =  y.copy()
total_test_set_prediction = []
kf = KFold(n_splits=5, random_state=False, shuffle=False)
for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    rf_model = RandomForestClassifier(max_depth = 5, n_estimators = 20,random_state=101)

    # fit the model
    rf_model.fit(X_train, y_train)
    # evaluate the model
    preds = rf_model.predict(X_test)
    test_preds  = rf_model.predict(X_test_cat_encoded)
    total_test_set_prediction.append(test_preds)
    #arr = np.stack([arr,test_preds],1)
    y__.iloc[test_index] = preds
    print('k-fold Accuracy : ',accuracy_score(y_test, preds))
print('Cross_validation_Accuracy : ',accuracy_score(y__, y))
test_pred_array = np.array(total_test_set_prediction)
test_pred_array_T = test_pred_array.transpose()
final_test_pred  = mode(test_pred_array_T,1)[0]
final_test_pred = final_test_pred.reshape((-1))

# %%
predicted_donors = pd.DataFrame()
predicted_donors['donated'] = final_test_pred
predicted_donors['control_no'] = test_control_no
predicted_donors.head()

# %%
predicted_donors['donated'].value_counts()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# * *Out of all the models used to predict whether a person has donates or not, the RandomForestClassifier performs well with an accuracy score of approximately 74.6%*
